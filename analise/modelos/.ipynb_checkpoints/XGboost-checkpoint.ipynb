# %% [markdown]
# ### Preliminares

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as pl

# %%
# Legenda para os códigos:
CodDescDict = {'CODIGO_CARGO': {6: 'DEPUTADO FEDERAL',7: 'DEPUTADO ESTADUAL',
  8: 'DEPUTADO DISTRITAL',13: 'VEREADOR'},
 'CODIGO_COR_RACA': {1: 'BRANCA',2: 'PRETA',3: 'PARDA',4: 'AMARELA',
  5: 'IND\xc3\x8dGENA'},
 'CODIGO_ESTADO_CIVIL': {0: 'N\xc3\x83O INFORMADO',1: 'SOLTEIRO(A)',
  3: 'CASADO(A)',5: 'VI\xc3\x9aVO(A)',7: 'SEPARADO(A) JUDICIALMENTE',
  9: 'DIVORCIADO(A)'},
 'CODIGO_NACIONALIDADE': {0: 'N\xc3\x83O INFORMADA',1: 'BRASILEIRA NATA',
  2: 'BRASILEIRA (NATURALIZADA)',3: 'PORTUGUESA COM IGUALDADE DE DIREITOS',
  4: 'ESTRANGEIRO'},
 'CODIGO_SEXO': {0: 'N\xc3\x83O INFORMADO', 2: 'MASCULINO', 4: 'FEMININO'},
 'COD_GRAU_INSTRUCAO': {0: 'N\xc3\x83O INFORMADO',1: 'ANALFABETO',
  2: 'L\xc3\x8a E ESCREVE',3: 'FUNDAMENTAL INCOMPLETO',
  4: 'FUNDAMENTAL COMPLETO',5: 'M\xc3\x89DIO INCOMPLETO',
  6: 'M\xc3\x89DIO COMPLETO',7: 'SUPERIOR INCOMPLETO',8: 'SUPERIOR COMPLETO'},
 'COD_SITUACAO_CANDIDATURA': {2: 'DEFERIDO',4: 'INDEFERIDO COM RECURSO',
  16: 'DEFERIDO COM RECURSO'},
 'NUMERO_PARTIDO': {10: 'PRB',11: 'PP',12: 'PDT',13: 'PT',14: 'PTB',
  15: 'MDB',16: 'PSTU',17: 'PSL',18: 'REDE',19: 'PODE',20: 'PSC',
  21: 'PCB',22: 'PR',23: 'PPS',25: 'DEM',26: 'PAN',27: 'DC',28: 'PRTB',
  29: 'PCO',30: 'NOVO',31: 'PHS',33: 'PMN',35: 'PMB',36: 'PTC',40: 'PSB',
  43: 'PV',44: 'PRP',45: 'PSDB',50: 'PSOL',51: 'PATRI',54: 'PPL',55: 'PSD',
  56: 'PRONA',65: 'PC do B',70: 'AVANTE',77: 'SD',90: 'PROS'}}

# %%
# Funções:

# Função que retorna número e completeza e pureza em %:
def NumComplPur(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    totTrue = cm[1,1]+cm[1,0]
    totSel  = cm[1,1]+cm[0,1]
    if totTrue==0:
        print 'Amostra vazia de fantasmas reais.'
        totTrue=1
    if totSel==0:
        print 'Amostra vazia de fantasmas selecionados.'
        totSel=1
    return [np.sum(cm[:,1]),float(cm[1,1])/totTrue*100,float(cm[1,1])/totSel*100]

def NumComplPurPrint(y_true, y_pred):
    n,c,p = NumComplPur(y_true, y_pred)
    print '# de selecionados como fantasmas: {}'.format(n)
    print 'Pureza dos selecionados: {:.2f}%'.format(p)
    print 'Completeza:              {:.2f}%'.format(c)

# %% [markdown]
# ### Carrega base de dados

# %%
# Carrega a base de dados já selecionados:
#base = pd.read_csv('../dadosParaModelar/deputados2010.csv')
base = pd.read_csv('../../dados/concatenados/completa+bens.csv',sep='>')

# IPCA para deflacionar valores (todos em outubro, com exceção de 2018 (em junho)):
anos   = [2004,2006,2008,2010,2012,2014,2016, 2018]
ipca   = np.array([608.7, 668.6, 740.8, 812.0, 915.6, 1033.0, 1224.9,1300.0])
deflate = dict(zip(anos,ipca[-1]/ipca))
DeflacBem = base.VALOR_BEM*(base.ANO_ELEICAO.map(deflate))
# COLOCA VALORES DEFLACIONADOS NA BASE:
base['VALOR_BEM_DEFLAC'] = DeflacBem

# Carrega categorias de profissões:
profBase = pd.read_csv('../profissoes-v2.txt',sep=';')
profDict = profBase.groupby('PROFISSAO')['CATEGORIA'].unique().apply(lambda x: x[-1]).to_dict()
# Out:
# /usr/lib/python2.7/dist-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (12,14,25,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
base18 = pd.read_csv('../../dados/concatenados/cand2018+anterior+bens.csv',sep='>')

# %% [markdown]
# ### Seleciona e prepara os dados

# %%
# Seleciona dados relevantes:
DataToModel = base.loc[(base.CODIGO_CARGO.isin([6,7,8])) & \
                       ((base.ANO_ELEICAO==2010) | (base.ANO_ELEICAO==2014)) & \
                       (base.CODIGO_SEXO==4)]\
[['ANO_ELEICAO','CODIGO_CARGO','CODIGO_ESTADO_CIVIL','CODIGO_NACIONALIDADE','COD_GRAU_INSTRUCAO',\
  'IDADE_DATA_ELEICAO','NUMERO_PARTIDO','SIGLA_UF',\
  'CODIGO_COR_RACA','DESCRICAO_OCUPACAO', 'TAMANHO_NOME', 'TAMANHO_NOME_URNA','TAMANHO_LEGENDA',\
   'NUM_ELEICOES_ANTERIORES','TOTAL_VOTOS_ANTERIORES','VALOR_BEM_DEFLAC','NUMERO_BENS','TOTAL_VOTOS']]

# Codifica as variáveis que ainda estão em forma de texto:
from sklearn.preprocessing import LabelEncoder
encoderUF = LabelEncoder()
DataToModel.SIGLA_UF = encoderUF.fit_transform(DataToModel.SIGLA_UF)
encoderCAT = LabelEncoder()
DataToModel = DataToModel.replace({'DESCRICAO_OCUPACAO': profDict})
DataToModel.DESCRICAO_OCUPACAO = encoderCAT.fit_transform(DataToModel.DESCRICAO_OCUPACAO)

# E ajusta as problemáticas:
DataToModel.TOTAL_VOTOS[DataToModel.TOTAL_VOTOS.isnull()==True] = -1
DataToModel.TOTAL_VOTOS_ANTERIORES[DataToModel.TOTAL_VOTOS_ANTERIORES.isnull()==True] = -1
DataToModel.NUMERO_BENS[DataToModel.NUMERO_BENS.isnull()==True] = -1
DataToModel.VALOR_BEM_DEFLAC[DataToModel.VALOR_BEM_DEFLAC.isnull()==True] = -1
DataToModel.CODIGO_COR_RACA[DataToModel.CODIGO_COR_RACA.isnull()==True] = -1

# Define o critério para ser fantasma:
DataToModel.TOTAL_VOTOS = ((DataToModel.TOTAL_VOTOS>=0) & \
                           (DataToModel.TOTAL_VOTOS<=5)).astype(int)

# %%
# Seleciona dados para aplicar o modelo:
DataToApply = base18.loc[(base18.CD_CARGO.isin([6,7,8])) & (base18.CD_GENERO==4)]\
[['CD_CARGO','CD_ESTADO_CIVIL','CD_NACIONALIDADE','CD_GRAU_INSTRUCAO',\
  'NR_IDADE_DATA_POSSE','NR_PARTIDO','SG_UF',\
  'CD_COR_RACA','DS_OCUPACAO', 'TAMANHO_NOME', 'TAMANHO_NOME_URNA','TAMANHO_LEGENDA',\
   'NUM_ELEICOES_ANTERIORES','TOTAL_VOTOS_ANTERIORES','VR_BEM_CANDIDATO','NUMERO_BENS']]

# Codifica as variáveis que ainda estão em forma de texto:
DataToApply.SG_UF = encoderUF.transform(DataToApply.SG_UF)
DataToApply = DataToApply.replace({'DS_OCUPACAO': profDict})
DataToApply.DS_OCUPACAO = encoderCAT.transform(DataToApply.DS_OCUPACAO)

# E ajusta as problemáticas:
DataToApply.TOTAL_VOTOS_ANTERIORES[DataToApply.TOTAL_VOTOS_ANTERIORES.isnull()==True] = -1
DataToApply.NUMERO_BENS[DataToApply.NUMERO_BENS.isnull()==True] = -1
DataToApply.VR_BEM_CANDIDATO[DataToApply.VR_BEM_CANDIDATO.isnull()==True] = -1
DataToApply.CD_COR_RACA[DataToApply.CD_COR_RACA.isnull()==True] = -1

# %%
# Separa dados disponíveis de futuros:

# Disponíveis:
X = DataToModel.loc[DataToModel.ANO_ELEICAO<2016].iloc[:,1:-1].values
y = DataToModel.loc[DataToModel.ANO_ELEICAO<2016].iloc[:,-1].values
# Futuros:
last_X = DataToModel.loc[DataToModel.ANO_ELEICAO==2014].iloc[:,1:-1].values
last_y = DataToModel.loc[DataToModel.ANO_ELEICAO==2014].iloc[:,-1].values

# %%
print 'Fração de fantasmas: {:.2f}%'\
.format(float(len(DataToModel.loc[DataToModel.TOTAL_VOTOS==1]))/len(DataToModel)*100)
# Out:
# Fração de fantasmas: 5.54%

# %% [markdown]
# ### Split & Treinamento

# %%
########################################
### Treinamento e previsão do modelo ###
########################################

# Divide os dados entre treinamento e teste:
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Treina o modelo nos dados:
# Se selecionarmos min_samples_leaf=2, parece que o modelo se torna, na 
# maioria das vezes, bem criterioso (alta pureza mas baixo número de 
# selecionados).
classifier = xgb.XGBClassifier()
classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %% [markdown]
# ### Teste do modelo

# %%
################################################################
### Análise dos resultados e comparação com amostra de teste ###
################################################################

# Prediz para a amostra de testes se são fantasmas ou não:
y_pred = classifier.predict(X_test)
NumComplPurPrint(y_test,y_pred)
# Out:
# # de selecionados como fantasmas: 19
# Pureza dos selecionados: 52.63%
# Completeza:              7.94%

# %%
# Teste com ano deixado de fora:
last_y_pred = classifier.predict(last_X)
NumComplPurPrint(last_y,last_y_pred)
# Out:
# # de selecionados como fantasmas: 40
# Pureza dos selecionados: 67.50%
# Completeza:              7.52%

# %%
# Vamos usar validaçao k-fold (do udemy):
#from sklearn.model_selection import cross_val_score
#accuracies = cross_val_score(classifier, X_train, y_train, cv=10, n_jobs=5)

# Cross-validation:
from sklearn.cross_validation import KFold
ncpKfold = []
kf = KFold(len(y_train), n_folds=10)
for train_index, test_index in kf:
   kf_X_train, kf_X_test = X_train[train_index], X_train[test_index]
   kf_y_train, kf_y_test = y_train[train_index], y_train[test_index]
   classifier.fit(kf_X_train, kf_y_train)
   ncpKfold.append(NumComplPur(kf_y_test, classifier.predict(kf_X_test)))
ncpMean = np.mean(ncpKfold,axis=0)
ncpDev  =  np.std(ncpKfold,axis=0,ddof=1)
print '== Cross-validation =='
print 'Núm.:   {}'.format(ncpMean[0],ncpDev[0])
print 'Pureza: {:.2f} +/- {:.2f} %'.format(ncpMean[2],ncpDev[2])
print 'Compl.: {:.2f} +/- {:.2f} %'.format(ncpMean[1],ncpDev[1])
# Out:
# == Cross-validation ==
# Núm.:   4.5
# Pureza: 63.20 +/- 28.66 %
# Compl.: 6.18 +/- 3.80 %

# %%
####################
### Optimization ###
####################

# Apply grid search
from sklearn.model_selection import GridSearchCV
hyper_pars = [{'max_depth':[0,3,4,5],
               'learning_rate':[0.15,0.2,0.25],
               'n_estimators':[50,75,100],
#               'n_jobs':[2],
               'gamma':[0.005,0.01,0.02],
               'subsample':[0.65,0.7,0.75,1]}]
grid_search = GridSearchCV(estimator = classifier, 
                           param_grid = hyper_pars,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs=8)
grid_search = grid_search.fit(X_train,y_train)
print grid_search.best_score_
print grid_search.best_params_
# Out:
# 0.954240631164
# {'n_estimators': 50, 'subsample': 0.65, 'learning_rate': 0.2, 'max_depth': 4, 'gamma': 0.005}

# %% [markdown]
# ### Características dos selecionados no TESTE

# %%
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# Vamos ver as características dos selecionados:
Xlabels   = DataToModel.columns.values[1:-1]
P_test    = classifier.predict_proba(X_test)
Pselected = P_test[y_pred==1]
Xselected = X_test[y_pred==1].astype(int)
Yselected = y_test[y_pred==1].astype(int)
selec = pd.DataFrame()
for i in range(0,len(Xlabels)):
    selec[Xlabels[i]] = pd.Series(Xselected[:,i])
for i in [0,1,2,3,5,7]:    
    selec[Xlabels[i]] = selec[Xlabels[i]].map(CodDescDict[Xlabels[i]])
selec['SIGLA_UF'] = encoderUF.inverse_transform(selec['SIGLA_UF'])
selec['DESCRICAO_OCUPACAO'] = encoderCAT.inverse_transform(selec['DESCRICAO_OCUPACAO'])
selec['PROB']     = pd.Series(Pselected[:,1])
selec['FANTASMA'] = pd.Series(Yselected)
selec.sort(columns='FANTASMA',ascending=False).transpose()
# Out:
#                                         18                      17  \
# CODIGO_CARGO             DEPUTADO ESTADUAL       DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)             SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA         BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO  FUNDAMENTAL INCOMPLETO
# IDADE_DATA_ELEICAO                      45                      41
# NUMERO_PARTIDO                          PP                    PSDB
# SIGLA_UF                                RR                      RR
# CODIGO_COR_RACA                        NaN                     NaN
# DESCRICAO_OCUPACAO          respostaoutros              donadecasa
# TAMANHO_NOME                             5                       4
# TAMANHO_NOME_URNA                        1                       1
# TAMANHO_LEGENDA                          1                       1
# NUM_ELEICOES_ANTERIORES                  0                       0
# TOTAL_VOTOS_ANTERIORES                   0                       0
# VALOR_BEM_DEFLAC                        -1                      -1
# NUMERO_BENS                             -1                      -1
# PROB                             0.5063965               0.5488781
# FANTASMA                                 1                       1
#
#                                         1                  2   \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      22                 29
# NUMERO_PARTIDO                         PMN                PPL
# SIGLA_UF                                RR                 AP
# CODIGO_COR_RACA                      PRETA             BRANCA
# DESCRICAO_OCUPACAO                agregado     respostaoutros
# TAMANHO_NOME                             4                  4
# TAMANHO_NOME_URNA                        1                  1
# TAMANHO_LEGENDA                          4                  6
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.7974184          0.5039637
# FANTASMA                                 1                  1
#
#                                         4                  7   \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      37                 21
# NUMERO_PARTIDO                        PRTB              PATRI
# SIGLA_UF                                RR                 AC
# CODIGO_COR_RACA                        NaN              PRETA
# DESCRICAO_OCUPACAO                agregado     respostaoutros
# TAMANHO_NOME                             3                  4
# TAMANHO_NOME_URNA                        1                  2
# TAMANHO_LEGENDA                          1                  3
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.5779616          0.5177827
# FANTASMA                                 1                  1
#
#                                         8                  0   \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      45                 28
# NUMERO_PARTIDO                        PROS                 PP
# SIGLA_UF                                RR                 RR
# CODIGO_COR_RACA                      PARDA              PRETA
# DESCRICAO_OCUPACAO          respostaoutros         donadecasa
# TAMANHO_NOME                             5                  5
# TAMANHO_NOME_URNA                        1                  2
# TAMANHO_LEGENDA                          7                  3
# NUM_ELEICOES_ANTERIORES                  1                  0
# TOTAL_VOTOS_ANTERIORES                   1                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.6990246          0.6240396
# FANTASMA                                 1                  1
#
#                                         11                   16  \
# CODIGO_CARGO             DEPUTADO ESTADUAL    DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL              CASADO(A)            CASADO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA      BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO  SUPERIOR INCOMPLETO
# IDADE_DATA_ELEICAO                      27                   31
# NUMERO_PARTIDO                         PPS                 PRTB
# SIGLA_UF                                RR                   RR
# CODIGO_COR_RACA                        NaN                  NaN
# DESCRICAO_OCUPACAO              batalhador           donadecasa
# TAMANHO_NOME                             4                    4
# TAMANHO_NOME_URNA                        1                    1
# TAMANHO_LEGENDA                          1                    1
# NUM_ELEICOES_ANTERIORES                  0                    0
# TOTAL_VOTOS_ANTERIORES                   0                    0
# VALOR_BEM_DEFLAC                        -1                   -1
# NUMERO_BENS                             -1                   -1
# PROB                             0.6982601             0.508425
# FANTASMA                                 1                    1
#
#                                         10                 12  \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)          CASADO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      33                 32
# NUMERO_PARTIDO                         PTB                 DC
# SIGLA_UF                                RR                 AC
# CODIGO_COR_RACA                        NaN                NaN
# DESCRICAO_OCUPACAO              batalhador         donadecasa
# TAMANHO_NOME                             3                  4
# TAMANHO_NOME_URNA                        1                  1
# TAMANHO_LEGENDA                          1                  1
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.6693055          0.5605985
# FANTASMA                                 0                  0
#
#                                         13                 6   \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO            LÊ E ESCREVE     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      24                 41
# NUMERO_PARTIDO                         PPL                PSL
# SIGLA_UF                                AC                 RR
# CODIGO_COR_RACA                      PARDA                NaN
# DESCRICAO_OCUPACAO          respostaoutros         batalhador
# TAMANHO_NOME                             4                  5
# TAMANHO_NOME_URNA                        2                  1
# TAMANHO_LEGENDA                          4                  1
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.5831744          0.5617297
# FANTASMA                                 0                  0
#
#                                         5                  14  \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      33                 34
# NUMERO_PARTIDO                     PC do B            PC do B
# SIGLA_UF                                RR                 RR
# CODIGO_COR_RACA                      PARDA                NaN
# DESCRICAO_OCUPACAO               estudante     respostaoutros
# TAMANHO_NOME                             4                  3
# TAMANHO_NOME_URNA                        1                  2
# TAMANHO_LEGENDA                          2                  1
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.5760106          0.5952203
# FANTASMA                                 0                  0
#
#                                         3                    15  \
# CODIGO_CARGO             DEPUTADO ESTADUAL    DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)          SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA      BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO  SUPERIOR INCOMPLETO
# IDADE_DATA_ELEICAO                      24                   22
# NUMERO_PARTIDO                         PSL                  PSB
# SIGLA_UF                                RR                   AC
# CODIGO_COR_RACA                        NaN                PARDA
# DESCRICAO_OCUPACAO          respostaoutros             agregado
# TAMANHO_NOME                             5                    3
# TAMANHO_NOME_URNA                        2                    2
# TAMANHO_LEGENDA                          1                    1
# NUM_ELEICOES_ANTERIORES                  0                    0
# TOTAL_VOTOS_ANTERIORES                   0                    0
# VALOR_BEM_DEFLAC                        -1                   -1
# NUMERO_BENS                             -1                   -1
# PROB                              0.513733            0.5631267
# FANTASMA                                 0                    0
#
#                                         9
# CODIGO_CARGO             DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      22
# NUMERO_PARTIDO                         PMN
# SIGLA_UF                                RR
# CODIGO_COR_RACA                      PARDA
# DESCRICAO_OCUPACAO              donadecasa
# TAMANHO_NOME                             4
# TAMANHO_NOME_URNA                        2
# TAMANHO_LEGENDA                          4
# NUM_ELEICOES_ANTERIORES                  0
# TOTAL_VOTOS_ANTERIORES                   0
# VALOR_BEM_DEFLAC                        -1
# NUMERO_BENS                             -1
# PROB                             0.6294882
# FANTASMA                                 0
#
# [18 rows x 19 columns]

# %%
# Plot feature importances:
features = pd.DataFrame()
features['nome'] = pd.Series(Xlabels)
features['importance'] = pd.Series(classifier.feature_importances_)
features = features.sort(columns='importance')

width = 0.35
fig, ax = pl.subplots()
barPos = np.arange(len(Xlabels))
ax.barh(barPos, np.array(features.importance),color='skyblue')
ax.set_yticks(barPos + width/2)
ax.set_yticklabels(features.nome.values)
pl.subplots_adjust(left=0.4)
pl.xlabel(u'Importância',fontsize=14)
pl.show()

# %% [markdown]
# ### Aplica modelo a dados de 2018

# %%
X18 = DataToApply.values
pred18 = classifier.predict(X18)
print 'Total de candidatos:', len(pred18)
print 'Total de suspeitos: ', len(pred18[pred18==1])
# Out:
# Total de candidatos: 8207
# Total de suspeitos:  33

# %%
# Vamos ver as características dos selecionados:
Xlabels   = DataToModel.columns.values[1:-1]
P_test    = classifier.predict_proba(X18)
Pselected = P_test[pred18==1]
Xselected = X18[pred18==1].astype(int)
selec18   = pd.DataFrame()
for i in range(0,len(Xlabels)):
    selec18[Xlabels[i]] = pd.Series(Xselected[:,i])
for i in [0,1,2,3,5,7]:    
    selec18[Xlabels[i]] = selec18[Xlabels[i]].map(CodDescDict[Xlabels[i]])
selec18['SIGLA_UF'] = encoderUF.inverse_transform(selec18['SIGLA_UF'])
selec18['DESCRICAO_OCUPACAO'] = encoderCAT.inverse_transform(selec18['DESCRICAO_OCUPACAO'])
selec18['PROB']     = pd.Series(Pselected[:,1])
selec18.transpose()
# Out:
#                                         0                  1   \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL              CASADO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO            LÊ E ESCREVE     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      65                 46
# NUMERO_PARTIDO                         PRB            PC do B
# SIGLA_UF                                AC                 AC
# CODIGO_COR_RACA                   INDÍGENA              PARDA
# DESCRICAO_OCUPACAO              donadecasa         donadecasa
# TAMANHO_NOME                             4                  4
# TAMANHO_NOME_URNA                        2                  2
# TAMANHO_LEGENDA                          3                  2
# NUM_ELEICOES_ANTERIORES                  0                  1
# TOTAL_VOTOS_ANTERIORES                   0                  1
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.5070323          0.5581725
#
#                                         2                  3   \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)          CASADO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      26                 42
# NUMERO_PARTIDO                         PTC                PSD
# SIGLA_UF                                RR                 RR
# CODIGO_COR_RACA                      PARDA              PARDA
# DESCRICAO_OCUPACAO                 gerente         donadecasa
# TAMANHO_NOME                             3                  5
# TAMANHO_NOME_URNA                        2                  2
# TAMANHO_LEGENDA                          1                  1
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.5562079          0.5761191
#
#                                         4                     5   \
# CODIGO_CARGO             DEPUTADO ESTADUAL     DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)             CASADO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA       BRASILEIRA NATA
# COD_GRAU_INSTRUCAO            LÊ E ESCREVE  FUNDAMENTAL COMPLETO
# IDADE_DATA_ELEICAO                      32                    39
# NUMERO_PARTIDO                        PROS                   PRB
# SIGLA_UF                                RR                    RR
# CODIGO_COR_RACA                     BRANCA                 PRETA
# DESCRICAO_OCUPACAO                precario              precario
# TAMANHO_NOME                             5                     3
# TAMANHO_NOME_URNA                        2                     2
# TAMANHO_LEGENDA                          3                     2
# NUM_ELEICOES_ANTERIORES                  0                     0
# TOTAL_VOTOS_ANTERIORES                   0                     0
# VALOR_BEM_DEFLAC                        -1                    -1
# NUMERO_BENS                             -1                    -1
# PROB                             0.5325636             0.5437607
#
#                                         6                  7   \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL          DIVORCIADO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      32                 36
# NUMERO_PARTIDO                          PT                PPL
# SIGLA_UF                                RR                 RR
# CODIGO_COR_RACA                      PRETA             BRANCA
# DESCRICAO_OCUPACAO              donadecasa               dono
# TAMANHO_NOME                             4                  4
# TAMANHO_NOME_URNA                        2                  1
# TAMANHO_LEGENDA                          3                  3
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                     40000             120000
# NUMERO_BENS                              1                  1
# PROB                              0.530499           0.566626
#
#                                         8                  9   \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL              CASADO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      28                 23
# NUMERO_PARTIDO                         PTC                MDB
# SIGLA_UF                                RR                 RR
# CODIGO_COR_RACA                      PARDA              PARDA
# DESCRICAO_OCUPACAO                 gerente          estudante
# TAMANHO_NOME                             3                  3
# TAMANHO_NOME_URNA                        2                  2
# TAMANHO_LEGENDA                          1                  1
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.5562079           0.515111
#
#                                         10                 11  \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL              CASADO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      27                 35
# NUMERO_PARTIDO                         PTB                PTB
# SIGLA_UF                                RR                 RR
# CODIGO_COR_RACA                      PARDA              PARDA
# DESCRICAO_OCUPACAO          respostaoutros     respostaoutros
# TAMANHO_NOME                             4                  5
# TAMANHO_NOME_URNA                        2                  2
# TAMANHO_LEGENDA                          3                  3
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.5010986          0.5010986
#
#                                         12                 13  \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      21                 28
# NUMERO_PARTIDO                          PR                PRB
# SIGLA_UF                                RR                 RR
# CODIGO_COR_RACA                      PARDA              PARDA
# DESCRICAO_OCUPACAO               estudante     respostaoutros
# TAMANHO_NOME                             4                  4
# TAMANHO_NOME_URNA                        2                  2
# TAMANHO_LEGENDA                          2                  2
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                              0.515111           0.635273
#
#                                         14                 15  \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      22                 27
# NUMERO_PARTIDO                         PTC               PRTB
# SIGLA_UF                                RR                 RR
# CODIGO_COR_RACA                      PARDA              PARDA
# DESCRICAO_OCUPACAO               estudante         agricultor
# TAMANHO_NOME                             5                  4
# TAMANHO_NOME_URNA                        2                  2
# TAMANHO_LEGENDA                          1                  2
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.5562079          0.5532931
#
#                                         16                 17  \
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)        SOLTEIRO(A)
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO
# IDADE_DATA_ELEICAO                      29                 20
# NUMERO_PARTIDO                          PR                PTC
# SIGLA_UF                                RR                 RR
# CODIGO_COR_RACA                      PARDA             BRANCA
# DESCRICAO_OCUPACAO                servidor     respostaoutros
# TAMANHO_NOME                             4                  4
# TAMANHO_NOME_URNA                        2                  2
# TAMANHO_LEGENDA                          2                  1
# NUM_ELEICOES_ANTERIORES                  0                  0
# TOTAL_VOTOS_ANTERIORES                   0                  0
# VALOR_BEM_DEFLAC                        -1                 -1
# NUMERO_BENS                             -1                 -1
# PROB                             0.5074061          0.5423278
#
#                                         18                 19
# CODIGO_CARGO             DEPUTADO ESTADUAL  DEPUTADO ESTADUAL ...
# CODIGO_ESTADO_CIVIL            SOLTEIRO(A)        SOLTEIRO(A) ...
# CODIGO_NACIONALIDADE       BRASILEIRA NATA    BRASILEIRA NATA ...
# COD_GRAU_INSTRUCAO          MÉDIO COMPLETO     MÉDIO COMPLETO ...
# IDADE_DATA_ELEICAO                      33                 23 ...
# NUMERO_PARTIDO                         PTB                PRB ...
# SIGLA_UF                                RR                 RR ...
# CODIGO_COR_RACA                      PARDA              PARDA ...
# DESCRICAO_OCUPACAO                agregado          estudante ...
# TAMANHO_NOME                             5                  5 ...
# TAMANHO_NOME_URNA                        2                  2 ...
# TAMANHO_LEGENDA                          3                  2 ...
# NUM_ELEICOES_ANTERIORES                  0                  0 ...
# TOTAL_VOTOS_ANTERIORES                   0                  0 ...
# VALOR_BEM_DEFLAC                        -1                 -1 ...
# NUMERO_BENS                             -1                 -1 ...
# PROB                             0.5368727          0.6481631 ...
#
# [17 rows x 33 columns]

# %% [markdown]
# ### Salva resultado dos suspeitos

# %%
baseSuspeitos = base18.loc[(base18.CD_CARGO.isin([6,7,8])) & (base18.CD_GENERO==4)].loc[pred18==1]

# %%
suspeitos18 = baseSuspeitos[['NM_CANDIDATO','NM_URNA_CANDIDATO','NR_CANDIDATO','SG_UF','NR_TITULO_ELEITORAL_CANDIDATO',\
                             'NR_CPF_CANDIDATO','DT_NASCIMENTO','NM_MUNICIPIO_NASCIMENTO','SG_UF_NASCIMENTO',\
                             'DS_GRAU_INSTRUCAO','DS_OCUPACAO','DS_COR_RACA','DS_ESTADO_CIVIL','NM_EMAIL',\
                             'SG_PARTIDO','DS_COMPOSICAO_COLIGACAO','DS_CARGO', 'NUM_ELEICOES_ANTERIORES',\
                             'TOTAL_VOTOS_ANTERIORES']]

# %%
suspeitos18.to_csv('cand-suspeitos-fantasmas-XGBoost-2018-08-26.csv',sep=';',index=False)
